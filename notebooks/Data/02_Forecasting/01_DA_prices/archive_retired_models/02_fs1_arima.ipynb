# %% [markdown]
# # 02 FS1 ARIMA
#
# This notebook covers the univariate ARIMA benchmark in the `FS1` layer: lagged day-ahead price information only, under the shared rolling-origin evaluation schedule.

# %%
from pathlib import Path
import json
import os
import subprocess
import sys
import time

import pandas as pd
from IPython.display import Image, display

NOTEBOOK_CWD = Path.cwd()
REPO_ROOT = next(
    path for path in [NOTEBOOK_CWD, *NOTEBOOK_CWD.parents] if (path / "scripts/Data/02_Forecasting/01_DA_prices").exists()
)
os.chdir(REPO_ROOT)
PACKAGE_ROOT = REPO_ROOT / "scripts/Data/02_Forecasting/01_DA_prices"
if str(PACKAGE_ROOT) not in sys.path:
    sys.path.append(str(PACKAGE_ROOT))

from hourly_da.core.config import HourlyDAPipelineConfig, MonitoringConfig
from hourly_da.core.reporting import find_latest_run, load_csv, load_json
from hourly_da.notebook_support import (
    apply_standard_matplotlib_style,
    build_compared_models_overview,
    build_dm_summary_table,
    build_model_style_map,
    build_week_metrics_for_predictions,
    build_reporting_metric_grid,
    build_reporting_summary_table,
    build_runtime_summary_table,
    estimate_run_duration_seconds,
    format_duration,
    load_selected_case_weeks,
    load_standard_report_bundle,
    render_plot_gallery,
    render_reporting_metric_dashboard,
    run_suite_with_feedback,
    style_dm_summary_table,
    style_model_overview_table,
    style_reporting_metric_grid,
    style_reporting_summary_table,
    style_runtime_summary_table,
    summarize_timing_compact,
    write_actual_vs_predicted_scatter_plot,
    write_horizon_error_plot,
    write_mae_by_hour_of_day_plot,
    write_residual_distribution_plot,
    write_standard_week_selection_plots,
    write_week_plots_for_models,
)

config = HourlyDAPipelineConfig(
    input_csv=REPO_ROOT / "data/01_cleaned/Day_ahead_prices/DA_prices/hourly/da_prices_all_regions_hourly.csv",
    raw_root=REPO_ROOT / "data/00_Raw/DA_Prices",
    cleaned_feature_root=REPO_ROOT / "data/01_cleaned",
    output_root=REPO_ROOT / "data/02_Forecasting/01_DA_prices/hourly_da",
)
output_root = config.output_root
run_root = output_root / "runs"


def latest_run_matching(pattern: str) -> Path:
    matches = sorted(run_root.glob(pattern))
    if not matches:
        raise FileNotFoundError(f"No run directories found for pattern: {pattern}")
    return matches[-1]

# %% [markdown]
# The optional rerun cell mirrors the `run_arima_benchmark.py` settings used in the saved artifacts.

# %%
ALLOW_HEAVY_RERUN = False

if ALLOW_HEAVY_RERUN:
    from dataclasses import replace

    from dataclasses import replace
    from hourly_da.models.arima import ARIMASettings, ARIMAModel
    from hourly_da.models.naive import PreviousWeekNaiveModel, PreviousYearNaiveModel
    rerun_config = replace(config)

    rerun_config = replace(config, monitoring=MonitoringConfig(fit_time_absolute_threshold_sec=5.0))
    arima_settings = ARIMASettings(history_window_hours=30 * 24, min_observed_history_hours=20 * 24, maxiter=10)
    models = [PreviousWeekNaiveModel(), PreviousYearNaiveModel(), ARIMAModel(settings=arima_settings)]
    rerun_payload = run_suite_with_feedback(
        config=rerun_config,
        run_label="arima_benchmark",
        models=models,
        include_external_features=False,
        show_progress=True,
        progress_label="arima_benchmark",
    )
    print(rerun_payload["official_naive"])
else:
    print("Rerun skipped. Set ALLOW_HEAVY_RERUN = True to execute the shared benchmark pipeline from this notebook.")
# Out:
# Rerun skipped. Set ALLOW_HEAVY_RERUN = True to execute the shared benchmark pipeline from this notebook.

# %%
run_dir = find_latest_run(output_root, "arima_benchmark")
print(run_dir)
# Out:
# C:\Users\marijnvalk\PycharmProjects\Thesis\data\02_Forecasting\01_DA_prices\hourly_da\runs\20260403_124458_arima_benchmark

# %% [markdown]
# The cells below use the shared **standardized thesis reporting layer**. The forecasting logic stays unchanged; only the post-run interpretation is organized into one consistent reporting sequence.

# %%
apply_standard_matplotlib_style()

current_suite_models = load_json(run_dir, "suite_models.json")["models"]
current_model_names = [record.get("name", record.get("model")) for record in current_suite_models]

COMPARISON_MODEL_SPECS = [{'model': 'naive_previous_week', 'display_name': 'Naive previous week', 'description': 'Official naive candidate from the same benchmark run.', 'role': 'benchmark'}, {'model': 'naive_previous_year', 'display_name': 'Naive previous year', 'description': 'Alternative naive benchmark from the same benchmark run.', 'role': 'benchmark'}, {'model': 'arima', 'display_name': 'ARIMA', 'description': 'Univariate ARIMA benchmark with lagged DA prices only.', 'role': 'current'}]
HORIZON_PLOT_MODELS = ['naive_previous_week', 'arima']
WEEK_PLOT_MODELS = ['naive_previous_week', 'naive_previous_year', 'arima']
DIAGNOSTIC_MODELS = ['naive_previous_week', 'arima']
DM_CHALLENGER_MODELS = ['arima']

report_bundle = load_standard_report_bundle(
    output_root=output_root,
    current_run_dir=run_dir,
    comparison_specs=COMPARISON_MODEL_SPECS,
)
model_styles = build_model_style_map(
    report_bundle["comparison_specs"],
    official_naive_model=str(report_bundle["official_naive"]["model"]),
)
report_output_dir = output_root / "notebook_artifacts" / "02_fs1_arima" / run_dir.name / "standard_report"
report_output_dir.mkdir(parents=True, exist_ok=True)

print(f"Current run: {run_dir.name}")
print(f"Current models: {current_model_names}")
print(f"Official naive benchmark: {report_bundle['official_naive']['model']}")
# Out:
# Current run: 20260403_124458_arima_benchmark
# Current models: ['naive_previous_week', 'naive_previous_year', 'arima']
# Official naive benchmark: naive_previous_week

# %% [markdown]
# ## 1. Short overview of compared models

# %%
overview_table = build_compared_models_overview(
    report_bundle["comparison_specs"],
    official_naive_model=str(report_bundle["official_naive"]["model"]),
)
display(style_model_overview_table(overview_table))
display(pd.DataFrame([report_bundle["official_naive"]]))
# Out:
# <style type="text/css">
# #T_16767  {
#   border-collapse: collapse;
#   width: 100%;
#   font-size: 12px;
# }
# #T_16767 th {
#   background: #edf3f7;
#   color: #183247;
#   padding: 8px 10px;
#   border: 1px solid #dce5eb;
# }
# #T_16767 td {
#   padding: 8px 10px;
#   border: 1px solid #e8edf1;
#   vertical-align: top;
# }
# #T_16767_row0_col0, #T_16767_row0_col1, #T_16767_row0_col2, #T_16767_row0_col3, #T_16767_row0_col4, #T_16767_row0_col5, #T_16767_row0_col6, #T_16767_row0_col8, #T_16767_row1_col0, #T_16767_row1_col1, #T_16767_row1_col2, #T_16767_row1_col3, #T_16767_row1_col4, #T_16767_row1_col5, #T_16767_row1_col6, #T_16767_row1_col7, #T_16767_row1_col8, #T_16767_row2_col0, #T_16767_row2_col1, #T_16767_row2_col2, #T_16767_row2_col3, #T_16767_row2_col4, #T_16767_row2_col5, #T_16767_row2_col6, #T_16767_row2_col7, #T_16767_row2_col8 {
#   background-color: #eef5fb;
#   font-weight: 600;
# }
# #T_16767_row0_col7 {
#   background-color: #eef5fb;
#   font-weight: 600;
#   background-color: #e4f1e6;
#   color: #1e5a2b;
#   font-weight: 700;
# }
# </style>
# <table id="T_16767">
#   <thead>
#     <tr>
#       <th id="T_16767_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_16767_level0_col1" class="col_heading level0 col1" >Internal model</th>
#       <th id="T_16767_level0_col2" class="col_heading level0 col2" >Family</th>
#       <th id="T_16767_level0_col3" class="col_heading level0 col3" >FS level</th>
#       <th id="T_16767_level0_col4" class="col_heading level0 col4" >Role</th>
#       <th id="T_16767_level0_col5" class="col_heading level0 col5" >Source scope</th>
#       <th id="T_16767_level0_col6" class="col_heading level0 col6" >Source run</th>
#       <th id="T_16767_level0_col7" class="col_heading level0 col7" >Official naive benchmark</th>
#       <th id="T_16767_level0_col8" class="col_heading level0 col8" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_16767_row0_col0" class="data row0 col0" >Naive previous week</td>
#       <td id="T_16767_row0_col1" class="data row0 col1" >naive_previous_week</td>
#       <td id="T_16767_row0_col2" class="data row0 col2" >naive</td>
#       <td id="T_16767_row0_col3" class="data row0 col3" >FS0</td>
#       <td id="T_16767_row0_col4" class="data row0 col4" >Benchmark</td>
#       <td id="T_16767_row0_col5" class="data row0 col5" >Current run</td>
#       <td id="T_16767_row0_col6" class="data row0 col6" >arima_benchmark</td>
#       <td id="T_16767_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_16767_row0_col8" class="data row0 col8" >Official naive candidate from the same benchmark run.</td>
#     </tr>
#     <tr>
#       <td id="T_16767_row1_col0" class="data row1 col0" >Naive previous year</td>
#       <td id="T_16767_row1_col1" class="data row1 col1" >naive_previous_year</td>
#       <td id="T_16767_row1_col2" class="data row1 col2" >naive</td>
#       <td id="T_16767_row1_col3" class="data row1 col3" >FS0</td>
#       <td id="T_16767_row1_col4" class="data row1 col4" >Benchmark</td>
#       <td id="T_16767_row1_col5" class="data row1 col5" >Current run</td>
#       <td id="T_16767_row1_col6" class="data row1 col6" >arima_benchmark</td>
#       <td id="T_16767_row1_col7" class="data row1 col7" ></td>
#       <td id="T_16767_row1_col8" class="data row1 col8" >Alternative naive benchmark from the same benchmark run.</td>
#     </tr>
#     <tr>
#       <td id="T_16767_row2_col0" class="data row2 col0" >ARIMA</td>
#       <td id="T_16767_row2_col1" class="data row2 col1" >arima</td>
#       <td id="T_16767_row2_col2" class="data row2 col2" >arima</td>
#       <td id="T_16767_row2_col3" class="data row2 col3" >FS1</td>
#       <td id="T_16767_row2_col4" class="data row2 col4" >Current</td>
#       <td id="T_16767_row2_col5" class="data row2 col5" >Current run</td>
#       <td id="T_16767_row2_col6" class="data row2 col6" >arima_benchmark</td>
#       <td id="T_16767_row2_col7" class="data row2 col7" ></td>
#       <td id="T_16767_row2_col8" class="data row2 col8" >Univariate ARIMA benchmark with lagged DA prices only.</td>
#     </tr>
#   </tbody>
# </table>
#                  model model_family fs_level dataset_split  \
# 0  naive_previous_week        naive      FS0    validation
#
#    observations_total  observations_scored  coverage_pct        mae  \
# 0               43440                42909     98.777624  27.857794
#
#         rmse      bias  ...  reporting_level_sort_order  reporting_lead_days  \
# 0  38.182575  0.523647  ...                           2            0,1,2,3,4
#
#   reporting_lead_day_start reporting_lead_day_end  reporting_lead_day_count  \
# 0                        0                      4                         5
#
#             selection_policy  selection_split  selection_reporting_level  \
# 0  minimum_coverage_then_mae       validation       stitched_all_horizon
#
#    selection_metric minimum_coverage_pct
# 0               mae                 95.0
#
# [1 rows x 24 columns]

# %% [markdown]
# ## 2. Main validation and test summary tables
#
# Each table reports the same thesis metrics for the three standard reporting slices:
# - `D only`
# - `Guidance only`
# - `Stitched all-horizon`

# %%
validation_summary = build_reporting_summary_table(
    report_bundle["metrics_by_reporting_level"],
    split_name="validation",
    model_order=report_bundle["model_order"],
)
test_summary = build_reporting_summary_table(
    report_bundle["metrics_by_reporting_level"],
    split_name="test",
    model_order=report_bundle["model_order"],
)

if not validation_summary.empty:
    display(style_reporting_summary_table(validation_summary, caption="Validation summary"))
if not test_summary.empty:
    display(style_reporting_summary_table(test_summary, caption="Test summary"))
# Out:
# <style type="text/css">
# #T_1db43 caption {
#   caption-side: top;
#   font-weight: 700;
#   font-size: 14px;
#   color: #183247;
#   padding-bottom: 6px;
# }
# #T_1db43  {
#   border-collapse: collapse;
#   width: 100%;
#   font-size: 12px;
# }
# #T_1db43 th {
#   background: #edf3f7;
#   color: #183247;
#   padding: 8px 10px;
#   border: 1px solid #dce5eb;
# }
# #T_1db43 td {
#   padding: 8px 10px;
#   border: 1px solid #e8edf1;
#   text-align: center;
# }
# #T_1db43 th.row_heading {
#   text-align: left;
#   background: #fbfcfd;
#   font-weight: 600;
# }
# #T_1db43_row0_col0, #T_1db43_row0_col1, #T_1db43_row0_col2, #T_1db43_row0_col3, #T_1db43_row0_col5, #T_1db43_row0_col6, #T_1db43_row0_col7, #T_1db43_row0_col10, #T_1db43_row0_col11, #T_1db43_row0_col12, #T_1db43_row2_col4, #T_1db43_row2_col8, #T_1db43_row2_col9, #T_1db43_row2_col13, #T_1db43_row2_col14 {
#   background-color: #e4f1e6;
#   color: #1e5a2b;
#   font-weight: 700;
# }
# </style>
# <table id="T_1db43">
#   <caption>Validation summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1db43_level0_col0" class="col_heading level0 col0" colspan="5">D only</th>
#       <th id="T_1db43_level0_col5" class="col_heading level0 col5" colspan="5">Guidance only</th>
#       <th id="T_1db43_level0_col10" class="col_heading level0 col10" colspan="5">Stitched all-horizon</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_1db43_level1_col0" class="col_heading level1 col0" >MAE</th>
#       <th id="T_1db43_level1_col1" class="col_heading level1 col1" >RMSE</th>
#       <th id="T_1db43_level1_col2" class="col_heading level1 col2" >rMAE</th>
#       <th id="T_1db43_level1_col3" class="col_heading level1 col3" >Bias</th>
#       <th id="T_1db43_level1_col4" class="col_heading level1 col4" >Coverage</th>
#       <th id="T_1db43_level1_col5" class="col_heading level1 col5" >MAE</th>
#       <th id="T_1db43_level1_col6" class="col_heading level1 col6" >RMSE</th>
#       <th id="T_1db43_level1_col7" class="col_heading level1 col7" >rMAE</th>
#       <th id="T_1db43_level1_col8" class="col_heading level1 col8" >Bias</th>
#       <th id="T_1db43_level1_col9" class="col_heading level1 col9" >Coverage</th>
#       <th id="T_1db43_level1_col10" class="col_heading level1 col10" >MAE</th>
#       <th id="T_1db43_level1_col11" class="col_heading level1 col11" >RMSE</th>
#       <th id="T_1db43_level1_col12" class="col_heading level1 col12" >rMAE</th>
#       <th id="T_1db43_level1_col13" class="col_heading level1 col13" >Bias</th>
#       <th id="T_1db43_level1_col14" class="col_heading level1 col14" >Coverage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1db43_level0_row0" class="row_heading level0 row0" >Naive previous week</th>
#       <td id="T_1db43_row0_col0" class="data row0 col0" >27.79</td>
#       <td id="T_1db43_row0_col1" class="data row0 col1" >38.13</td>
#       <td id="T_1db43_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_1db43_row0_col3" class="data row0 col3" >+0.35</td>
#       <td id="T_1db43_row0_col4" class="data row0 col4" >98.77%</td>
#       <td id="T_1db43_row0_col5" class="data row0 col5" >27.87</td>
#       <td id="T_1db43_row0_col6" class="data row0 col6" >38.20</td>
#       <td id="T_1db43_row0_col7" class="data row0 col7" >1.000</td>
#       <td id="T_1db43_row0_col8" class="data row0 col8" >+0.57</td>
#       <td id="T_1db43_row0_col9" class="data row0 col9" >98.78%</td>
#       <td id="T_1db43_row0_col10" class="data row0 col10" >27.86</td>
#       <td id="T_1db43_row0_col11" class="data row0 col11" >38.18</td>
#       <td id="T_1db43_row0_col12" class="data row0 col12" >1.000</td>
#       <td id="T_1db43_row0_col13" class="data row0 col13" >+0.52</td>
#       <td id="T_1db43_row0_col14" class="data row0 col14" >98.78%</td>
#     </tr>
#     <tr>
#       <th id="T_1db43_level0_row1" class="row_heading level0 row1" >Naive previous year</th>
#       <td id="T_1db43_row1_col0" class="data row1 col0" >65.60</td>
#       <td id="T_1db43_row1_col1" class="data row1 col1" >94.95</td>
#       <td id="T_1db43_row1_col2" class="data row1 col2" >2.360</td>
#       <td id="T_1db43_row1_col3" class="data row1 col3" >+51.11</td>
#       <td id="T_1db43_row1_col4" class="data row1 col4" >98.86%</td>
#       <td id="T_1db43_row1_col5" class="data row1 col5" >65.31</td>
#       <td id="T_1db43_row1_col6" class="data row1 col6" >94.41</td>
#       <td id="T_1db43_row1_col7" class="data row1 col7" >2.343</td>
#       <td id="T_1db43_row1_col8" class="data row1 col8" >+50.89</td>
#       <td id="T_1db43_row1_col9" class="data row1 col9" >98.88%</td>
#       <td id="T_1db43_row1_col10" class="data row1 col10" >65.37</td>
#       <td id="T_1db43_row1_col11" class="data row1 col11" >94.51</td>
#       <td id="T_1db43_row1_col12" class="data row1 col12" >2.346</td>
#       <td id="T_1db43_row1_col13" class="data row1 col13" >+50.93</td>
#       <td id="T_1db43_row1_col14" class="data row1 col14" >98.87%</td>
#     </tr>
#     <tr>
#       <th id="T_1db43_level0_row2" class="row_heading level0 row2" >ARIMA</th>
#       <td id="T_1db43_row2_col0" class="data row2 col0" >28.84</td>
#       <td id="T_1db43_row2_col1" class="data row2 col1" >40.09</td>
#       <td id="T_1db43_row2_col2" class="data row2 col2" >1.038</td>
#       <td id="T_1db43_row2_col3" class="data row2 col3" >-1.18</td>
#       <td id="T_1db43_row2_col4" class="data row2 col4" >99.39%</td>
#       <td id="T_1db43_row2_col5" class="data row2 col5" >32.99</td>
#       <td id="T_1db43_row2_col6" class="data row2 col6" >44.09</td>
#       <td id="T_1db43_row2_col7" class="data row2 col7" >1.184</td>
#       <td id="T_1db43_row2_col8" class="data row2 col8" >-0.06</td>
#       <td id="T_1db43_row2_col9" class="data row2 col9" >99.40%</td>
#       <td id="T_1db43_row2_col10" class="data row2 col10" >32.16</td>
#       <td id="T_1db43_row2_col11" class="data row2 col11" >43.32</td>
#       <td id="T_1db43_row2_col12" class="data row2 col12" >1.155</td>
#       <td id="T_1db43_row2_col13" class="data row2 col13" >-0.28</td>
#       <td id="T_1db43_row2_col14" class="data row2 col14" >99.40%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_92560 caption {
#   caption-side: top;
#   font-weight: 700;
#   font-size: 14px;
#   color: #183247;
#   padding-bottom: 6px;
# }
# #T_92560  {
#   border-collapse: collapse;
#   width: 100%;
#   font-size: 12px;
# }
# #T_92560 th {
#   background: #edf3f7;
#   color: #183247;
#   padding: 8px 10px;
#   border: 1px solid #dce5eb;
# }
# #T_92560 td {
#   padding: 8px 10px;
#   border: 1px solid #e8edf1;
#   text-align: center;
# }
# #T_92560 th.row_heading {
#   text-align: left;
#   background: #fbfcfd;
#   font-weight: 600;
# }
# #T_92560_row0_col0, #T_92560_row0_col2, #T_92560_row0_col3, #T_92560_row0_col5, #T_92560_row0_col6, #T_92560_row0_col7, #T_92560_row0_col8, #T_92560_row0_col10, #T_92560_row0_col11, #T_92560_row0_col12, #T_92560_row0_col13, #T_92560_row2_col1, #T_92560_row2_col4, #T_92560_row2_col9, #T_92560_row2_col14 {
#   background-color: #e4f1e6;
#   color: #1e5a2b;
#   font-weight: 700;
# }
# </style>
# <table id="T_92560">
#   <caption>Test summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92560_level0_col0" class="col_heading level0 col0" colspan="5">D only</th>
#       <th id="T_92560_level0_col5" class="col_heading level0 col5" colspan="5">Guidance only</th>
#       <th id="T_92560_level0_col10" class="col_heading level0 col10" colspan="5">Stitched all-horizon</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_92560_level1_col0" class="col_heading level1 col0" >MAE</th>
#       <th id="T_92560_level1_col1" class="col_heading level1 col1" >RMSE</th>
#       <th id="T_92560_level1_col2" class="col_heading level1 col2" >rMAE</th>
#       <th id="T_92560_level1_col3" class="col_heading level1 col3" >Bias</th>
#       <th id="T_92560_level1_col4" class="col_heading level1 col4" >Coverage</th>
#       <th id="T_92560_level1_col5" class="col_heading level1 col5" >MAE</th>
#       <th id="T_92560_level1_col6" class="col_heading level1 col6" >RMSE</th>
#       <th id="T_92560_level1_col7" class="col_heading level1 col7" >rMAE</th>
#       <th id="T_92560_level1_col8" class="col_heading level1 col8" >Bias</th>
#       <th id="T_92560_level1_col9" class="col_heading level1 col9" >Coverage</th>
#       <th id="T_92560_level1_col10" class="col_heading level1 col10" >MAE</th>
#       <th id="T_92560_level1_col11" class="col_heading level1 col11" >RMSE</th>
#       <th id="T_92560_level1_col12" class="col_heading level1 col12" >rMAE</th>
#       <th id="T_92560_level1_col13" class="col_heading level1 col13" >Bias</th>
#       <th id="T_92560_level1_col14" class="col_heading level1 col14" >Coverage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92560_level0_row0" class="row_heading level0 row0" >Naive previous week</th>
#       <td id="T_92560_row0_col0" class="data row0 col0" >33.10</td>
#       <td id="T_92560_row0_col1" class="data row0 col1" >54.48</td>
#       <td id="T_92560_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_92560_row0_col3" class="data row0 col3" >-0.47</td>
#       <td id="T_92560_row0_col4" class="data row0 col4" >98.63%</td>
#       <td id="T_92560_row0_col5" class="data row0 col5" >33.14</td>
#       <td id="T_92560_row0_col6" class="data row0 col6" >54.54</td>
#       <td id="T_92560_row0_col7" class="data row0 col7" >1.000</td>
#       <td id="T_92560_row0_col8" class="data row0 col8" >-0.67</td>
#       <td id="T_92560_row0_col9" class="data row0 col9" >98.59%</td>
#       <td id="T_92560_row0_col10" class="data row0 col10" >33.13</td>
#       <td id="T_92560_row0_col11" class="data row0 col11" >54.53</td>
#       <td id="T_92560_row0_col12" class="data row0 col12" >1.000</td>
#       <td id="T_92560_row0_col13" class="data row0 col13" >-0.63</td>
#       <td id="T_92560_row0_col14" class="data row0 col14" >98.60%</td>
#     </tr>
#     <tr>
#       <th id="T_92560_level0_row1" class="row_heading level0 row1" >Naive previous year</th>
#       <td id="T_92560_row1_col0" class="data row1 col0" >39.98</td>
#       <td id="T_92560_row1_col1" class="data row1 col1" >56.15</td>
#       <td id="T_92560_row1_col2" class="data row1 col2" >1.208</td>
#       <td id="T_92560_row1_col3" class="data row1 col3" >-17.04</td>
#       <td id="T_92560_row1_col4" class="data row1 col4" >98.67%</td>
#       <td id="T_92560_row1_col5" class="data row1 col5" >40.17</td>
#       <td id="T_92560_row1_col6" class="data row1 col6" >56.33</td>
#       <td id="T_92560_row1_col7" class="data row1 col7" >1.212</td>
#       <td id="T_92560_row1_col8" class="data row1 col8" >-17.47</td>
#       <td id="T_92560_row1_col9" class="data row1 col9" >98.68%</td>
#       <td id="T_92560_row1_col10" class="data row1 col10" >40.13</td>
#       <td id="T_92560_row1_col11" class="data row1 col11" >56.29</td>
#       <td id="T_92560_row1_col12" class="data row1 col12" >1.211</td>
#       <td id="T_92560_row1_col13" class="data row1 col13" >-17.38</td>
#       <td id="T_92560_row1_col14" class="data row1 col14" >98.67%</td>
#     </tr>
#     <tr>
#       <th id="T_92560_level0_row2" class="row_heading level0 row2" >ARIMA</th>
#       <td id="T_92560_row2_col0" class="data row2 col0" >35.18</td>
#       <td id="T_92560_row2_col1" class="data row2 col1" >50.93</td>
#       <td id="T_92560_row2_col2" class="data row2 col2" >1.063</td>
#       <td id="T_92560_row2_col3" class="data row2 col3" >-2.97</td>
#       <td id="T_92560_row2_col4" class="data row2 col4" >99.30%</td>
#       <td id="T_92560_row2_col5" class="data row2 col5" >39.85</td>
#       <td id="T_92560_row2_col6" class="data row2 col6" >56.67</td>
#       <td id="T_92560_row2_col7" class="data row2 col7" >1.203</td>
#       <td id="T_92560_row2_col8" class="data row2 col8" >-2.43</td>
#       <td id="T_92560_row2_col9" class="data row2 col9" >99.29%</td>
#       <td id="T_92560_row2_col10" class="data row2 col10" >38.92</td>
#       <td id="T_92560_row2_col11" class="data row2 col11" >55.57</td>
#       <td id="T_92560_row2_col12" class="data row2 col12" >1.175</td>
#       <td id="T_92560_row2_col13" class="data row2 col13" >-2.53</td>
#       <td id="T_92560_row2_col14" class="data row2 col14" >99.29%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. By-horizon error view
#
# This figure keeps the split fixed and shows how MAE changes from `D` through `D+4`.

# %%
horizon_plot_path = write_horizon_error_plot(
    metrics_by_lead_day=report_bundle["metrics_by_lead_day"][
        report_bundle["metrics_by_lead_day"]["model"].isin(HORIZON_PLOT_MODELS)
    ].copy(),
    output_path=report_output_dir / "horizon_error_mae.png",
    model_order=HORIZON_PLOT_MODELS,
    model_styles=model_styles,
)
if horizon_plot_path is not None:
    display(Image(filename=str(horizon_plot_path)))

# %% [markdown]
# ## 4. Forecast vs actual on the frozen week selections
#
# These plots reuse the objectively selected weeks from notebook `00`. For a clean visual comparison, the overlays use the operational `D only` path so each target hour appears once.

# %%
selection_run_dir, selected_weeks = load_selected_case_weeks(output_root)
display(selected_weeks[["category", "iso_week_id", "week_start_local_date", "week_end_local_date"]])

model_label_map = (
    report_bundle["comparison_specs"][["model", "display_name"]]
    .drop_duplicates(subset=["model"])
    .set_index("model")["display_name"]
    .to_dict()
)
week_metrics = build_week_metrics_for_predictions(report_bundle["predictions_long"], config, selected_weeks)
week_metrics_display = (
    week_metrics[week_metrics["model"].isin(WEEK_PLOT_MODELS)]
    .assign(Model=lambda frame: frame["model"].map(model_label_map).fillna(frame["model"]))
    [["category", "iso_week_id", "Model", "mae", "rmse", "bias", "coverage_pct", "max_abs_error"]]
    .sort_values(["category", "mae", "Model"])
    .reset_index(drop=True)
)
display(
    week_metrics_display.style
    .format(
        {
            "mae": "{:.2f}",
            "rmse": "{:.2f}",
            "bias": "{:+.2f}",
            "coverage_pct": "{:.2f}%",
            "max_abs_error": "{:.2f}",
        }
    )
    .hide(axis="index")
)

week_plot_paths = write_standard_week_selection_plots(
    predictions=report_bundle["predictions_long"],
    config=config,
    selected_weeks=selected_weeks,
    output_dir=report_output_dir / "week_plots",
    model_order=WEEK_PLOT_MODELS,
    model_styles=model_styles,
    split_name="test",
    reporting_level="d_only",
    title_prefix='FS1 ARIMA, D-only path',
)
display(render_plot_gallery(week_plot_paths, columns=2))
# Out:
#           category iso_week_id week_start_local_date week_end_local_date
# 0       high_price    2025-W07            2025-02-10          2025-02-16
# 1  high_volatility    2024-W50            2024-12-09          2024-12-15
# 2        low_price    2025-W38            2025-09-15          2025-09-21
# 3   negative_price    2025-W20            2025-05-12          2025-05-18
# 4   typical_summer    2025-W34            2025-08-18          2025-08-24
# 5   typical_winter    2025-W08            2025-02-17          2025-02-23
# <style type="text/css">
# </style>
# <table id="T_59f85">
#   <thead>
#     <tr>
#       <th id="T_59f85_level0_col0" class="col_heading level0 col0" >category</th>
#       <th id="T_59f85_level0_col1" class="col_heading level0 col1" >iso_week_id</th>
#       <th id="T_59f85_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_59f85_level0_col3" class="col_heading level0 col3" >mae</th>
#       <th id="T_59f85_level0_col4" class="col_heading level0 col4" >rmse</th>
#       <th id="T_59f85_level0_col5" class="col_heading level0 col5" >bias</th>
#       <th id="T_59f85_level0_col6" class="col_heading level0 col6" >coverage_pct</th>
#       <th id="T_59f85_level0_col7" class="col_heading level0 col7" >max_abs_error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_59f85_row0_col0" class="data row0 col0" >high_price</td>
#       <td id="T_59f85_row0_col1" class="data row0 col1" >2025-W07</td>
#       <td id="T_59f85_row0_col2" class="data row0 col2" >ARIMA</td>
#       <td id="T_59f85_row0_col3" class="data row0 col3" >26.40</td>
#       <td id="T_59f85_row0_col4" class="data row0 col4" >33.44</td>
#       <td id="T_59f85_row0_col5" class="data row0 col5" >-1.22</td>
#       <td id="T_59f85_row0_col6" class="data row0 col6" >100.00%</td>
#       <td id="T_59f85_row0_col7" class="data row0 col7" >111.41</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row1_col0" class="data row1 col0" >high_price</td>
#       <td id="T_59f85_row1_col1" class="data row1 col1" >2025-W07</td>
#       <td id="T_59f85_row1_col2" class="data row1 col2" >Naive previous week</td>
#       <td id="T_59f85_row1_col3" class="data row1 col3" >28.41</td>
#       <td id="T_59f85_row1_col4" class="data row1 col4" >37.50</td>
#       <td id="T_59f85_row1_col5" class="data row1 col5" >-11.51</td>
#       <td id="T_59f85_row1_col6" class="data row1 col6" >98.21%</td>
#       <td id="T_59f85_row1_col7" class="data row1 col7" >132.26</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row2_col0" class="data row2 col0" >high_price</td>
#       <td id="T_59f85_row2_col1" class="data row2 col1" >2025-W07</td>
#       <td id="T_59f85_row2_col2" class="data row2 col2" >Naive previous year</td>
#       <td id="T_59f85_row2_col3" class="data row2 col3" >74.03</td>
#       <td id="T_59f85_row2_col4" class="data row2 col4" >79.60</td>
#       <td id="T_59f85_row2_col5" class="data row2 col5" >-73.96</td>
#       <td id="T_59f85_row2_col6" class="data row2 col6" >99.40%</td>
#       <td id="T_59f85_row2_col7" class="data row2 col7" >193.61</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row3_col0" class="data row3 col0" >high_volatility</td>
#       <td id="T_59f85_row3_col1" class="data row3 col1" >2024-W50</td>
#       <td id="T_59f85_row3_col2" class="data row3 col2" >Naive previous week</td>
#       <td id="T_59f85_row3_col3" class="data row3 col3" >72.61</td>
#       <td id="T_59f85_row3_col4" class="data row3 col4" >136.04</td>
#       <td id="T_59f85_row3_col5" class="data row3 col5" >-54.90</td>
#       <td id="T_59f85_row3_col6" class="data row3 col6" >100.00%</td>
#       <td id="T_59f85_row3_col7" class="data row3 col7" >735.06</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row4_col0" class="data row4 col0" >high_volatility</td>
#       <td id="T_59f85_row4_col1" class="data row4 col1" >2024-W50</td>
#       <td id="T_59f85_row4_col2" class="data row4 col2" >ARIMA</td>
#       <td id="T_59f85_row4_col3" class="data row4 col3" >72.67</td>
#       <td id="T_59f85_row4_col4" class="data row4 col4" >132.01</td>
#       <td id="T_59f85_row4_col5" class="data row4 col5" >-45.76</td>
#       <td id="T_59f85_row4_col6" class="data row4 col6" >100.00%</td>
#       <td id="T_59f85_row4_col7" class="data row4 col7" >707.74</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row5_col0" class="data row5 col0" >high_volatility</td>
#       <td id="T_59f85_row5_col1" class="data row5 col1" >2024-W50</td>
#       <td id="T_59f85_row5_col2" class="data row5 col2" >Naive previous year</td>
#       <td id="T_59f85_row5_col3" class="data row5 col3" >91.13</td>
#       <td id="T_59f85_row5_col4" class="data row5 col4" >151.71</td>
#       <td id="T_59f85_row5_col5" class="data row5 col5" >-79.41</td>
#       <td id="T_59f85_row5_col6" class="data row5 col6" >99.40%</td>
#       <td id="T_59f85_row5_col7" class="data row5 col7" >768.83</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row6_col0" class="data row6 col0" >low_price</td>
#       <td id="T_59f85_row6_col1" class="data row6 col1" >2025-W38</td>
#       <td id="T_59f85_row6_col2" class="data row6 col2" >Naive previous year</td>
#       <td id="T_59f85_row6_col3" class="data row6 col3" >34.80</td>
#       <td id="T_59f85_row6_col4" class="data row6 col4" >51.23</td>
#       <td id="T_59f85_row6_col5" class="data row6 col5" >+24.16</td>
#       <td id="T_59f85_row6_col6" class="data row6 col6" >97.62%</td>
#       <td id="T_59f85_row6_col7" class="data row6 col7" >239.77</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row7_col0" class="data row7 col0" >low_price</td>
#       <td id="T_59f85_row7_col1" class="data row7 col1" >2025-W38</td>
#       <td id="T_59f85_row7_col2" class="data row7 col2" >ARIMA</td>
#       <td id="T_59f85_row7_col3" class="data row7 col3" >45.05</td>
#       <td id="T_59f85_row7_col4" class="data row7 col4" >55.97</td>
#       <td id="T_59f85_row7_col5" class="data row7 col5" >+7.09</td>
#       <td id="T_59f85_row7_col6" class="data row7 col6" >97.62%</td>
#       <td id="T_59f85_row7_col7" class="data row7 col7" >313.66</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row8_col0" class="data row8 col0" >low_price</td>
#       <td id="T_59f85_row8_col1" class="data row8 col1" >2025-W38</td>
#       <td id="T_59f85_row8_col2" class="data row8 col2" >Naive previous week</td>
#       <td id="T_59f85_row8_col3" class="data row8 col3" >54.56</td>
#       <td id="T_59f85_row8_col4" class="data row8 col4" >77.59</td>
#       <td id="T_59f85_row8_col5" class="data row8 col5" >+34.82</td>
#       <td id="T_59f85_row8_col6" class="data row8 col6" >96.43%</td>
#       <td id="T_59f85_row8_col7" class="data row8 col7" >327.78</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row9_col0" class="data row9 col0" >negative_price</td>
#       <td id="T_59f85_row9_col1" class="data row9 col1" >2025-W20</td>
#       <td id="T_59f85_row9_col2" class="data row9 col2" >Naive previous week</td>
#       <td id="T_59f85_row9_col3" class="data row9 col3" >29.15</td>
#       <td id="T_59f85_row9_col4" class="data row9 col4" >55.74</td>
#       <td id="T_59f85_row9_col5" class="data row9 col5" >+3.83</td>
#       <td id="T_59f85_row9_col6" class="data row9 col6" >99.40%</td>
#       <td id="T_59f85_row9_col7" class="data row9 col7" >342.63</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row10_col0" class="data row10 col0" >negative_price</td>
#       <td id="T_59f85_row10_col1" class="data row10 col1" >2025-W20</td>
#       <td id="T_59f85_row10_col2" class="data row10 col2" >Naive previous year</td>
#       <td id="T_59f85_row10_col3" class="data row10 col3" >33.10</td>
#       <td id="T_59f85_row10_col4" class="data row10 col4" >44.19</td>
#       <td id="T_59f85_row10_col5" class="data row10 col5" >-16.65</td>
#       <td id="T_59f85_row10_col6" class="data row10 col6" >99.40%</td>
#       <td id="T_59f85_row10_col7" class="data row10 col7" >143.04</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row11_col0" class="data row11 col0" >negative_price</td>
#       <td id="T_59f85_row11_col1" class="data row11 col1" >2025-W20</td>
#       <td id="T_59f85_row11_col2" class="data row11 col2" >ARIMA</td>
#       <td id="T_59f85_row11_col3" class="data row11 col3" >50.76</td>
#       <td id="T_59f85_row11_col4" class="data row11 col4" >57.63</td>
#       <td id="T_59f85_row11_col5" class="data row11 col5" >-2.56</td>
#       <td id="T_59f85_row11_col6" class="data row11 col6" >100.00%</td>
#       <td id="T_59f85_row11_col7" class="data row11 col7" >152.02</td>
#     </tr>
#     <tr>
#       <td id="T_59f85_row12_col0" class="data row12 col0" >typical_summer</td>
#       <td id="T_59f85_row12_col1" class="data row12 col1" >2025-W34</td>
#       <td id="T_59f85_ro
#         <style>
#         .plot-gallery-grid {
#             display: grid;
#             gap: 16px;
#             align-items: start;
#         }
#         .plot-gallery-card {
#             border: 1px solid #dde4ea;
#             border-radius: 16px;
#             background: #ffffff;
#             box-shadow: 0 8px 20px rgba(16, 24, 40, 0.06);
#             padding: 10px;
#         }
#         @media (max-width: 1100px) {
#             .plot-gallery-grid {
#                 grid-template-columns: 1fr !important;
#             }
#         }
#         </style>
#         <div class='plot-gallery-grid' style='grid-template-columns: repeat(2, minmax(0, 1fr));'><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div></div>

# %% [markdown]
# ## 5. Diagnostic plots
#
# The diagnostics below focus on the **test split** and the same `D only` operational path as the week overlays, so the interpretation is based on unique forecast-target pairs rather than repeated multi-origin horizons.

# %%
diagnostic_plot_paths = []

mae_by_hour_path = write_mae_by_hour_of_day_plot(
    predictions=report_bundle["predictions_long"],
    config=config,
    output_path=report_output_dir / "diagnostics" / "mae_by_hour_of_day.png",
    model_order=DIAGNOSTIC_MODELS,
    model_styles=model_styles,
)
if mae_by_hour_path is not None:
    diagnostic_plot_paths.append(mae_by_hour_path)

residual_path = write_residual_distribution_plot(
    predictions=report_bundle["predictions_long"],
    config=config,
    output_path=report_output_dir / "diagnostics" / "residual_distribution.png",
    model_order=DIAGNOSTIC_MODELS,
    model_styles=model_styles,
)
if residual_path is not None:
    diagnostic_plot_paths.append(residual_path)

scatter_path = write_actual_vs_predicted_scatter_plot(
    predictions=report_bundle["predictions_long"],
    config=config,
    output_path=report_output_dir / "diagnostics" / "actual_vs_predicted.png",
    model_order=DIAGNOSTIC_MODELS,
    model_styles=model_styles,
)
if scatter_path is not None:
    diagnostic_plot_paths.append(scatter_path)

display(render_plot_gallery(diagnostic_plot_paths, columns=2))
# Out:
#         <style>
#         .plot-gallery-grid {
#             display: grid;
#             gap: 16px;
#             align-items: start;
#         }
#         .plot-gallery-card {
#             border: 1px solid #dde4ea;
#             border-radius: 16px;
#             background: #ffffff;
#             box-shadow: 0 8px 20px rgba(16, 24, 40, 0.06);
#             padding: 10px;
#         }
#         @media (max-width: 1100px) {
#             .plot-gallery-grid {
#                 grid-template-columns: 1fr !important;
#             }
#         }
#         </style>
#         <div class='plot-gallery-grid' style='grid-template-columns: repeat(2, minmax(0, 1fr));'><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div><div class='plot-gallery-card'><img src='data:image/png;base64,...' style='width: 100%; height: auto; display: block; border-radius: 14px;'/></div></div>

# %% [markdown]
# ## 6. Statistical comparison
#
# The Diebold-Mariano table is interpreted as follows:
# - negative DM statistic favors the challenger
# - positive DM statistic favors the benchmark
# - the verdict column applies a `p < 0.05` threshold

# %%
dm_display_order = [
    row["display_name"]
    for row in report_bundle["comparison_specs"].to_dict(orient="records")
    if row["model"] in DM_CHALLENGER_MODELS
]
dm_summary = build_dm_summary_table(
    report_bundle["diebold_mariano_by_reporting_level"][
        report_bundle["diebold_mariano_by_reporting_level"]["challenger_model"].isin(DM_CHALLENGER_MODELS)
    ].copy(),
    challenger_display_order=dm_display_order,
)
if dm_summary.empty:
    print("No configured Diebold-Mariano comparisons were available for this notebook.")
else:
    display(style_dm_summary_table(dm_summary))
# Out:
# <style type="text/css">
# #T_46e7a  {
#   border-collapse: collapse;
#   width: 100%;
#   font-size: 12px;
# }
# #T_46e7a th {
#   background: #edf3f7;
#   color: #183247;
#   padding: 8px 10px;
#   border: 1px solid #dce5eb;
# }
# #T_46e7a td {
#   padding: 8px 10px;
#   border: 1px solid #e8edf1;
# }
# #T_46e7a_row0_col7, #T_46e7a_row3_col7 {
#   background-color: #f7f8fa;
#   color: #52606d;
# }
# #T_46e7a_row1_col7, #T_46e7a_row2_col7, #T_46e7a_row4_col7, #T_46e7a_row5_col7 {
#   background-color: #f7e4e4;
#   color: #7a2f2f;
#   font-weight: 700;
# }
# </style>
# <table id="T_46e7a">
#   <thead>
#     <tr>
#       <th id="T_46e7a_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_46e7a_level0_col1" class="col_heading level0 col1" >Challenger</th>
#       <th id="T_46e7a_level0_col2" class="col_heading level0 col2" >Benchmark</th>
#       <th id="T_46e7a_level0_col3" class="col_heading level0 col3" >Reporting level</th>
#       <th id="T_46e7a_level0_col4" class="col_heading level0 col4" >Observations</th>
#       <th id="T_46e7a_level0_col5" class="col_heading level0 col5" >DM stat</th>
#       <th id="T_46e7a_level0_col6" class="col_heading level0 col6" >p-value</th>
#       <th id="T_46e7a_level0_col7" class="col_heading level0 col7" >Verdict</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_46e7a_row0_col0" class="data row0 col0" >test</td>
#       <td id="T_46e7a_row0_col1" class="data row0 col1" >ARIMA</td>
#       <td id="T_46e7a_row0_col2" class="data row0 col2" >Naive previous week</td>
#       <td id="T_46e7a_row0_col3" class="data row0 col3" >D only</td>
#       <td id="T_46e7a_row0_col4" class="data row0 col4" >8,545</td>
#       <td id="T_46e7a_row0_col5" class="data row0 col5" >1.35</td>
#       <td id="T_46e7a_row0_col6" class="data row0 col6" >0.178</td>
#       <td id="T_46e7a_row0_col7" class="data row0 col7" >No significant difference</td>
#     </tr>
#     <tr>
#       <td id="T_46e7a_row1_col0" class="data row1 col0" >test</td>
#       <td id="T_46e7a_row1_col1" class="data row1 col1" >ARIMA</td>
#       <td id="T_46e7a_row1_col2" class="data row1 col2" >Naive previous week</td>
#       <td id="T_46e7a_row1_col3" class="data row1 col3" >Guidance only</td>
#       <td id="T_46e7a_row1_col4" class="data row1 col4" >34,168</td>
#       <td id="T_46e7a_row1_col5" class="data row1 col5" >9.34</td>
#       <td id="T_46e7a_row1_col6" class="data row1 col6" ><0.001</td>
#       <td id="T_46e7a_row1_col7" class="data row1 col7" >Benchmark better</td>
#     </tr>
#     <tr>
#       <td id="T_46e7a_row2_col0" class="data row2 col0" >test</td>
#       <td id="T_46e7a_row2_col1" class="data row2 col1" >ARIMA</td>
#       <td id="T_46e7a_row2_col2" class="data row2 col2" >Naive previous week</td>
#       <td id="T_46e7a_row2_col3" class="data row2 col3" >Stitched all-horizon</td>
#       <td id="T_46e7a_row2_col4" class="data row2 col4" >42,713</td>
#       <td id="T_46e7a_row2_col5" class="data row2 col5" >8.92</td>
#       <td id="T_46e7a_row2_col6" class="data row2 col6" ><0.001</td>
#       <td id="T_46e7a_row2_col7" class="data row2 col7" >Benchmark better</td>
#     </tr>
#     <tr>
#       <td id="T_46e7a_row3_col0" class="data row3 col0" >validation</td>
#       <td id="T_46e7a_row3_col1" class="data row3 col1" >ARIMA</td>
#       <td id="T_46e7a_row3_col2" class="data row3 col2" >Naive previous week</td>
#       <td id="T_46e7a_row3_col3" class="data row3 col3" >D only</td>
#       <td id="T_46e7a_row3_col4" class="data row3 col4" >8,581</td>
#       <td id="T_46e7a_row3_col5" class="data row3 col5" >1.08</td>
#       <td id="T_46e7a_row3_col6" class="data row3 col6" >0.281</td>
#       <td id="T_46e7a_row3_col7" class="data row3 col7" >No significant difference</td>
#     </tr>
#     <tr>
#       <td id="T_46e7a_row4_col0" class="data row4 col0" >validation</td>
#       <td id="T_46e7a_row4_col1" class="data row4 col1" >ARIMA</td>
#       <td id="T_46e7a_row4_col2" class="data row4 col2" >Naive previous week</td>
#       <td id="T_46e7a_row4_col3" class="data row4 col3" >Guidance only</td>
#       <td id="T_46e7a_row4_col4" class="data row4 col4" >34,328</td>
#       <td id="T_46e7a_row4_col5" class="data row4 col5" >10.80</td>
#       <td id="T_46e7a_row4_col6" class="data row4 col6" ><0.001</td>
#       <td id="T_46e7a_row4_col7" class="data row4 col7" >Benchmark better</td>
#     </tr>
#     <tr>
#       <td id="T_46e7a_row5_col0" class="data row5 col0" >validation</td>
#       <td id="T_46e7a_row5_col1" class="data row5 col1" >ARIMA</td>
#       <td id="T_46e7a_row5_col2" class="data row5 col2" >Naive previous week</td>
#       <td id="T_46e7a_row5_col3" class="data row5 col3" >Stitched all-horizon</td>
#       <td id="T_46e7a_row5_col4" class="data row5 col4" >42,909</td>
#       <td id="T_46e7a_row5_col5" class="data row5 col5" >10.08</td>
#       <td id="T_46e7a_row5_col6" class="data row5 col6" ><0.001</td>
#       <td id="T_46e7a_row5_col7" class="data row5 col7" >Benchmark better</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 7. Runtime and practicality summary

# %%
runtime_summary = build_runtime_summary_table(
    report_bundle["timing_summary"],
    model_order=report_bundle["model_order"],
)
if runtime_summary.empty:
    print("No runtime summary was available for this notebook.")
else:
    display(style_runtime_summary_table(runtime_summary))
# Out:
# <style type="text/css">
# #T_a0ce0  {
#   border-collapse: collapse;
#   width: 100%;
#   font-size: 12px;
# }
# #T_a0ce0 th {
#   background: #edf3f7;
#   color: #183247;
#   padding: 8px 10px;
#   border: 1px solid #dce5eb;
# }
# #T_a0ce0 td {
#   padding: 8px 10px;
#   border: 1px solid #e8edf1;
# }
# </style>
# <table id="T_a0ce0">
#   <thead>
#     <tr>
#       <th id="T_a0ce0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a0ce0_level0_col1" class="col_heading level0 col1" >Split</th>
#       <th id="T_a0ce0_level0_col2" class="col_heading level0 col2" >Origins</th>
#       <th id="T_a0ce0_level0_col3" class="col_heading level0 col3" >Fit mean (s)</th>
#       <th id="T_a0ce0_level0_col4" class="col_heading level0 col4" >Predict mean (s)</th>
#       <th id="T_a0ce0_level0_col5" class="col_heading level0 col5" >Fit max (s)</th>
#       <th id="T_a0ce0_level0_col6" class="col_heading level0 col6" >Fit warnings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a0ce0_row0_col0" class="data row0 col0" >Naive previous week</td>
#       <td id="T_a0ce0_row0_col1" class="data row0 col1" >validation</td>
#       <td id="T_a0ce0_row0_col2" class="data row0 col2" >362</td>
#       <td id="T_a0ce0_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_a0ce0_row0_col4" class="data row0 col4" >0.0429</td>
#       <td id="T_a0ce0_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_a0ce0_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a0ce0_row1_col0" class="data row1 col0" >Naive previous week</td>
#       <td id="T_a0ce0_row1_col1" class="data row1 col1" >test</td>
#       <td id="T_a0ce0_row1_col2" class="data row1 col2" >361</td>
#       <td id="T_a0ce0_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_a0ce0_row1_col4" class="data row1 col4" >0.0467</td>
#       <td id="T_a0ce0_row1_col5" class="data row1 col5" >0.0001</td>
#       <td id="T_a0ce0_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a0ce0_row2_col0" class="data row2 col0" >Naive previous year</td>
#       <td id="T_a0ce0_row2_col1" class="data row2 col1" >validation</td>
#       <td id="T_a0ce0_row2_col2" class="data row2 col2" >362</td>
#       <td id="T_a0ce0_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_a0ce0_row2_col4" class="data row2 col4" >0.0428</td>
#       <td id="T_a0ce0_row2_col5" class="data row2 col5" >0.0001</td>
#       <td id="T_a0ce0_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a0ce0_row3_col0" class="data row3 col0" >Naive previous year</td>
#       <td id="T_a0ce0_row3_col1" class="data row3 col1" >test</td>
#       <td id="T_a0ce0_row3_col2" class="data row3 col2" >361</td>
#       <td id="T_a0ce0_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_a0ce0_row3_col4" class="data row3 col4" >0.0466</td>
#       <td id="T_a0ce0_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_a0ce0_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a0ce0_row4_col0" class="data row4 col0" >ARIMA</td>
#       <td id="T_a0ce0_row4_col1" class="data row4 col1" >validation</td>
#       <td id="T_a0ce0_row4_col2" class="data row4 col2" >362</td>
#       <td id="T_a0ce0_row4_col3" class="data row4 col3" >0.271</td>
#       <td id="T_a0ce0_row4_col4" class="data row4 col4" >0.0084</td>
#       <td id="T_a0ce0_row4_col5" class="data row4 col5" >0.414</td>
#       <td id="T_a0ce0_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <td id="T_a0ce0_row5_col0" class="data row5 col0" >ARIMA</td>
#       <td id="T_a0ce0_row5_col1" class="data row5 col1" >test</td>
#       <td id="T_a0ce0_row5_col2" class="data row5 col2" >361</td>
#       <td id="T_a0ce0_row5_col3" class="data row5 col3" >0.273</td>
#       <td id="T_a0ce0_row5_col4" class="data row5 col4" >0.0084</td>
#       <td id="T_a0ce0_row5_col5" class="data row5 col5" >0.615</td>
#       <td id="T_a0ce0_row5_col6" class="data row5 col6" >0</td>
#     </tr>
#   </tbody>
# </table>
